# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# f = cv2.imread("images/images/Lenna.png")
f = cv2.imread("cv_2026_docker/images/images/Lenna.png",0)
# print(f)

plt.imshow(f, cmap='gray')
# cv2.imshow("Lenna",f)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
print(type(f[0,0,0]))
print(f.shape)
print(f[:,:,0])
print(f[:,:,1])
print(f[:,:,2])
# Out:
# <class 'numpy.uint8'>
# (220, 220, 3)
# [[127 127 119 ... 128 124 104]
#  [127 127 119 ... 130 126 105]
#  [122 118 117 ... 106  96  80]
#  ...
#  [ 60  61  63 ...  68  73  73]
#  [ 61  62  61 ...  78  80  78]
#  [ 58  62  59 ...  84  81  80]]
# [[137 137 134 ... 141 150 120]
#  [137 136 134 ... 144 155 124]
#  [137 134 133 ... 113  97  61]
#  ...
#  [ 28  29  28 ...  42  58  59]
#  [ 24  27  25 ...  58  67  65]
#  [ 22  29  24 ...  67  70  71]]
# [[225 224 227 ... 227 232 213]
#  [225 224 227 ... 230 238 219]
#  [227 224 228 ... 209 189 149]
#  ...
#  [ 90  95  97 ... 126 148 158]
#  [ 87  92  95 ... 143 167 169]
#  [ 84  95  93 ... 159 176 182]]

# %%
f1 = cv2.imread("cv_2026_docker/images/images/seal.jpg",0)
f2 = cv2.imread("cv_2026_docker/images/images/sea.jpg",0)


g1 = cv2.resize(f1,(600,400))
g2 = cv2.resize(f2,(600,400))

output = np.uint8((g1+g2)/2)
output = np.uint8(0.7*g1+0.3*g2)
# print(output)
g = cv2.resize(f,(100,50))
plt.imshow(output,cmap="gray")

# %% [markdown]
# ## 시각화

# %%
x = np.array([1,2,3,4,5])
y = x ** 2

print(y)

plt.plot(x,y,'-or')
plt.grid()
# Out:
# [ 1  4  9 16 25]

# %%
f = cv2.imread("cv_2026_docker/images/images/Lenna.png",0)
plt.imshow(f, cmap="gray")
