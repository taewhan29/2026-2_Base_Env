# %% [markdown]
# # <감마 변환>

# %% [markdown]
# ## 기본 라이브러리 불러오기

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## 사용자 파라미터(parameter) 정의하기

# %%
gamma =

# %% [markdown]
# ## 'Lenna.png'를 흑백영상으로 읽어오기

# %%
f = 
h,w = f.shape

# %% [markdown]
# ## 결과 영상(g)를 생성하고, 감마 변환 구현하기

# %%
g =

# %% [markdown]
# ## 결과 영상 출력하기

# %%
plt.imshow(,cmap="gray")
